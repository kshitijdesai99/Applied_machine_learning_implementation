# %%
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import train_test_split

# Define columns to use
columns_finalized = ['ResponseId', 'Age', 'Employment', 'DevType', 'AISelect', 'EdLevel', 'LearnCode', 'YearsCode',
                     'LanguageHaveWorkedWith', 'Country', 'OpSysPersonal use', 'NEWCollabToolsHaveWorkedWith',
                     'LanguageWantToWorkWith', 'OfficeStackSyncHaveWorkedWith', 'RemoteWork', 'ToolsTechHaveWorkedWith',
                     'DatabaseHaveWorkedWith', 'LearnCodeOnline', 'OrgSize', 'ToolsTechWantToWorkWith', 'BuyNewTool',
                     'WebframeHaveWorkedWith', 'AIThreat', 'ToolsTechAdmired', 'BuildvsBuy', 'DatabaseWantToWorkWith',
                     'PlatformHaveWorkedWith', 'AIEthics', 'TechDoc', 'YearsCodePro', 'MiscTechHaveWorkedWith',
                     'DatabaseAdmired', 'WebframeWantToWorkWith', 'WebframeAdmired', 'ConvertedCompYearly',
                     'MiscTechWantToWorkWith', 'WorkExp', 'MiscTechAdmired', 'JobSat', 'TimeSearching', 'Industry',
                     'TimeAnswering', 'ProfessionalQuestion', 'ProfessionalCloud', 'Frustration', 'ProfessionalTech']

def load_and_preprocess_data(file_path, columns):
    df = (pd.read_csv(file_path, usecols=columns)
          .fillna("empty")
          .query("DevType != 'empty' and DevType != 'Other (please specify):'")
          .reset_index(drop=True))
    return df

def combine_skills(df, columns, new_column_name):
    df[new_column_name] = (df[columns]
                           .fillna('')
                           .agg(';'.join, axis=1)
                           .apply(lambda x: x.split(';') if x else []))
    return df

def create_job_profiles(df):
    job_profiles = df.groupby('DevType').agg({
        'LanguageHaveWorkedWith': lambda x: ';'.join([str(i) for i in x if pd.notna(i) and i != 'empty']),
        'ToolsTechHaveWorkedWith': lambda x: ';'.join([str(i) for i in x if pd.notna(i) and i != 'empty']),
        'PlatformHaveWorkedWith': lambda x: ';'.join([str(i) for i in x if pd.notna(i) and i != 'empty']),
        'MiscTechHaveWorkedWith': lambda x: ';'.join([str(i) for i in x if pd.notna(i) and i != 'empty']),
        'WebframeHaveWorkedWith': lambda x: ';'.join([str(i) for i in x if pd.notna(i) and i != 'empty']),
        'DatabaseHaveWorkedWith': lambda x: ';'.join([str(i) for i in x if pd.notna(i) and i != 'empty']),
    }).reset_index()

    def clean_skills(skill_str):
        skills = skill_str.split(';')
        return dict(Counter(skills))

    def top_skills(skill_dict, n=10):
        return sorted(skill_dict, key=skill_dict.get, reverse=True)[:n]

    column_mapping = {
        'Languages': 'LanguageHaveWorkedWith',
        'Tools': 'ToolsTechHaveWorkedWith',
        'WebFrameworks': 'WebframeHaveWorkedWith',
        'Databases': 'DatabaseHaveWorkedWith',
        'Platforms': 'PlatformHaveWorkedWith',
        'MiscTechs': 'MiscTechHaveWorkedWith'
    }

    for col, original_col in column_mapping.items():
        job_profiles[col] = job_profiles[original_col].apply(clean_skills)
        job_profiles[f'Top{col}'] = job_profiles[col].apply(lambda x: top_skills(x, 10))

    job_profiles = job_profiles[['DevType', 'TopLanguages', 'TopTools', 'TopWebFrameworks', 'TopDatabases',
                                 'TopPlatforms', 'TopMiscTechs']]
    return job_profiles

def jaccard_similarity(user_skills, job_skills):
    user_skillz = set(user_skills) - {'empty'}
    job_skillz = set(job_skills) - {'empty'}
    intersection = len(user_skillz.intersection(job_skillz))
    union = len(user_skillz.union(job_skillz))
    return intersection / union if union != 0 else 0

def create_interaction_matrix(df_have, job_profiles):
    interaction_matrix = pd.DataFrame(index=df_have['ResponseId'], columns=job_profiles['DevType'])
    for user_id, user_skills in df_have[['ResponseId', 'AllSkillsHaveWorkedWith']].itertuples(index=False):
        for DevType, TopLanguages, TopTools, TopWebFrameworks, TopDatabases, TopPlatforms, TopMiscTechs in job_profiles.itertuples(index=False):
            job_skill_set = TopLanguages + TopTools + TopWebFrameworks + TopDatabases + TopPlatforms + TopMiscTechs
            similarity_score = jaccard_similarity(user_skills, job_skill_set)
            interaction_matrix.at[user_id, DevType] = similarity_score
    return interaction_matrix.fillna(0)

def train_svd_model(interaction_matrix, n_components=10):
    svd = TruncatedSVD(n_components=n_components)
    user_factors = svd.fit_transform(interaction_matrix)
    job_factors = svd.components_.T
    return svd, user_factors, job_factors

def recommend_jobs_for_user(user_id, reconstructed_matrix, n=5):
    user_scores = reconstructed_matrix.loc[user_id]
    top_jobs = user_scores.nlargest(n).index.tolist()
    return top_jobs

def calculate_mrr(true_jobs, predicted_jobs):
    mrr = 0.0
    for user_index, true_job in enumerate(true_jobs):
        try:
            rank = np.where(predicted_jobs[user_index] == true_job)[0][0] + 1
            mrr += 1 / rank
        except IndexError:
            continue
    return mrr / len(true_jobs)

# %%
# Load and preprocess data
df = load_and_preprocess_data("survey_results_public.csv", columns_finalized)
df = combine_skills(df, ['LanguageHaveWorkedWith', 'ToolsTechHaveWorkedWith', 'PlatformHaveWorkedWith',
                         'MiscTechHaveWorkedWith', 'WebframeHaveWorkedWith', 'DatabaseHaveWorkedWith'], 
                    'AllSkillsHaveWorkedWith')
df = combine_skills(df, ['LanguageWantToWorkWith', 'ToolsTechWantToWorkWith', 'WebframeWantToWorkWith',
                         'MiscTechWantToWorkWith', 'DatabaseWantToWorkWith'], 
                    'AllSkillsWantToWorkWith')

# Filter out students
df_non_students = df.query("DevType != 'Student'").reset_index(drop=True)

# %%
# from sklearn.model_selection import StratifiedShuffleSplit

# split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
# for train_idx, test_idx in split.split(df_non_students, df_non_students['DevType']):
#     train_df = df_non_students.iloc[train_idx].reset_index(drop=True)
#     test_df = df_non_students.iloc[test_idx].reset_index(drop=True)

# %%
train_df = df_non_students[:len(df_non_students)-5000].copy()
test_df = df_non_students[len(df_non_students)-5000:].copy()

# %%
with pd.option_context('display.max_rows', 5, 'display.max_columns', None):
    display(train_df)
# Out:
#        ResponseId              Age           Employment RemoteWork  \
# 0               2  35-44 years old  Employed, full-time     Remote
# 1               3  45-54 years old  Employed, full-time     Remote
# ...           ...              ...                  ...        ...
# 46883       55784  35-44 years old  Employed, full-time     Remote
# 46884       55785  55-64 years old  Employed, full-time  In-person
#
#                                                EdLevel  \
# 0         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                ...
# 46883  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 46884   Professional degree (JD, MD, Ph.D, Ed.D, etc.)
#
#                                                LearnCode  \
# 0      Books / Physical media;Colleague;On the job tr...
# 1      Books / Physical media;Colleague;On the job tr...
# ...                                                  ...
# 46883  Books / Physical media;On the job training;Oth...
# 46884  Books / Physical media;Other online resources ...
#
#                                          LearnCodeOnline  \
# 0      Technical documentation;Blogs;Books;Written Tu...
# 1      Technical documentation;Blogs;Books;Written Tu...
# ...                                                  ...
# 46883  Technical documentation;Blogs;Written Tutorial...
# 46884  Technical documentation;Books;Written Tutorial...
#
#                                                  TechDoc YearsCode  \
# 0      API document(s) and/or SDK document(s);User gu...        20
# 1      API document(s) and/or SDK document(s);User gu...        37
# ...                                                  ...       ...
# 46883  API document(s) and/or SDK document(s);User gu...        22
# 46884  API document(s) and/or SDK document(s);First-p...        44
#
#       YearsCodePro                        DevType                   OrgSize  \
# 0               17          Developer, full-stack                     empty
# 1               27           Developer Experience                     empty
# ...            ...                            ...                       ...
# 46883           17  Cloud infrastructure engineer  10,000 or more employees
# 46884           22            Academic researcher      500 to 999 employees
#
#                                               BuyNewTool  \
# 0                                                  empty
# 1                                                  empty
# ...                                                  ...
# 46883  Start a free trial;Ask developers I know/work ...
# 46884  Start a free trial;Ask developers I know/work ...
#
#                                               BuildvsBuy  \
# 0                                                  empty
# 1                                                  empty
# ...                                                  ...
# 46883  Is ready-to-go but also customizable for growt...
# 46884  Is set up to be customized and needs to be eng...
#
#                                                  Country  \
# 0      United Kingdom of Great Britain and Northern I...
# 1      United Kingdom of Great Britain and Northern I...
# ...                                                  ...
# 46883                                             Greece
# 46884                                             Canada
#
#                                   LanguageHaveWorkedWith  \
# 0      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 1                                                     C#
# ...                                                  ...
# 46883                                       C#;Go;Python
# 46884  Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
#
#                                   LanguageWantToWorkWith  \
# 0      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 1                                                     C#
# ...                                                  ...
# 46883                                          Go;Python
# 46884  Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
#
#                   DatabaseHaveWorkedWith           DatabaseWantToWorkWith  \
# 0            Dynamodb;MongoDB;PostgreSQL                       PostgreSQL
# 1             Firebase Realtime Database       Firebase Realtime Database
# ...                                  ...                              ...
# 46883  Cosmos DB;Databricks SQL;Dynamodb                BigQuery;Dynamodb
# 46884       MariaDB;MongoDB;MySQL;SQLite  MariaDB;MySQL;PostgreSQL;SQLite
#
#                   DatabaseAdmired  \
# 0                      PostgreSQL
# 1      Firebase Realtime Database
# ...                           ...
# 46883                    Dynamodb
# 46884        MariaDB;MySQL;SQLite
#
#                                   PlatformHaveWorkedWith  \
# 0               Amazon Web Services (AWS);Heroku;Netlify
# 1                                           Google Cloud
# ...                                                  ...
# 46883  Amazon Web Services (AWS);Databricks;Google Cl...
# 46884                              Heroku;PythonAnywhere
#
#               WebframeHaveWorkedWith  \
# 0      Express;Next.js;Node.js;React
# 1                       ASP.NET CORE
# ...                              ...
# 46883                   ASP.NET CORE
# 46884    Django;jQuery;Node.js;React
#
#                               WebframeWantToWorkWith        WebframeAdmired  \
# 0                   Express;Htmx;Node.js;React;Remix  Express;Node.js;React
# 1                                       ASP.NET CORE           ASP.NET CORE
# ...                                              ...                    ...
# 46883                                   ASP.NET CORE           ASP.NET CORE
# 46884  Django;Flask;Node.js;React;Spring Boot;Vue.js   Django;Node.js;React
#
#                                   MiscTechHaveWorkedWith  \
# 0                                                  empty
# 1        .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# ...                                                  ...
# 46883                                              NumPy
# 46884  CUDA;NumPy;Pandas;Scikit-Learn;Spring Framewor...
#
#                                   MiscTechWantToWorkWith  \
# 0                                                  empty
# 1        .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# ...                                                  ...
# 46883                                              NumPy
# 46884  CUDA;Electron;Hugging Face Transformers;NumPy;...
#
#                                          MiscTechAdmired  \
# 0                                                  empty
# 1        .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# ...                                                  ...
# 46883                                              NumPy
# 46884  CUDA;NumPy;Pandas;Scikit-Learn;Spring Framewor...
#
#                                  ToolsTechHaveWorkedWith  \
# 0            Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 1                                                MSBuild
# ...                                                  ...
# 46883  Ansible;Docker;Homebrew;Kubernetes;npm;Pip;Ter...
# 46884  Chocolatey;Gradle;Maven (build tool);npm;Pip;V...
#
#                                  ToolsTechWantToWorkWith  \
# 0            Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 1                                                MSBuild
# ...                                                  ...
# 46883  Ansible;Docker;Homebrew;Kubernetes;npm;Pip;Ter...
# 46884       Docker;Kubernetes;Maven (build tool);npm;Pip
#
#                                         ToolsTechAdmired  \
# 0            Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 1                                                MSBuild
# ...                                                  ...
# 46883  Ansible;Docker;Homebrew;Kubernetes;npm;Pip;Ter...
# 46884                         Maven (build tool);npm;Pip
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                    PyCharm;Visual Studio Code;WebStorm
# 1                                          Visual Studio
# ...                                                  ...
# 46883                                 Visual Studio Code
# 46884  Eclipse;IntelliJ IDEA;Jupyter Notebook/Jupyter...
#
#                                     OpSysPersonal use  \
# 0                                       MacOS;Windows
# 1                                             Windows
# ...                                               ...
# 46883                                  Ubuntu;Windows
# 46884  Arch;Windows;Windows Subsystem for Linux (WSL)
#
#                          OfficeStackSyncHaveWorkedWith  \
# 0                                Microsoft Teams;Slack
# 1         Google Chat;Google Meet;Microsoft Teams;Zoom
# ...                                                ...
# 46883                                  Microsoft Teams
# 46884  Cisco Webex Teams;Microsoft Teams;Whatsapp;Zoom
#
#                       AISelect      AIThreat  \
# 0      No, and I don't plan to         empty
# 1      No, and I don't plan to         empty
# ...                        ...           ...
# 46883                      Yes  I'm not sure
# 46884                      Yes           Yes
#
#                                                 AIEthics WorkExp  \
# 0                                                  empty    17.0
# 1                                                  empty   empty
# ...                                                  ...     ...
# 46883  Circulating misinformation or disinformation;M...    22.0
# 46884  Circulating misinformation or disinformation;B...    25.0
#
#                 TimeSearching         TimeAnswering  \
# 0                       empty                 empty
# 1                       empty                 empty
# ...                       ...                   ...
# 46883     30-60 minutes a day  60-120 minutes a day
# 46884  Over 120 minutes a day   30-60 minutes a day
#
#                                              Frustration  \
# 0                                                  empty
# 1                                                  empty
# ...                                                  ...
# 46883  Tracking my work;Showing my contributions;Patc...
# 46884  Amount of technical debt;Showing my contributi...
#
#                                         ProfessionalTech  \
# 0                                                  empty
# 1                                                  empty
# ...                                                  ...
# 46883  DevOps function;Observability tools;AI-assiste...
# 46884  Automated testing;Developer portal or other ce...
#
#                 ProfessionalCloud  \
# 0                           empty
# 1                           empty
# ...                           ...
# 46883  Hybrid (on-prem and cloud)
# 46884  Hybrid (on-prem and cloud)
#
#                                     ProfessionalQuestion  \
# 0                                                  empty
# 1                                                  empty
# ...                                                  ...
# 46883  Do search of internal share drives/storage loc...
# 46884                   Traditional public search engine
#
#                            Industry ConvertedCompYearly JobSat  \
# 0                             empty               empty  empty
# 1                             empty               empty  empty
# ...                             ...                 ...    ...
# 46883  Retail and Consumer Services               empty    9.0
# 46884              Higher Education               empty    7.0
#
#                                  AllSkillsHaveWorkedWith  \
# 0      [Bash/Shell (all shells), Go, HTML/CSS, Java, ...
# 1      [C#, MSBuild, Google Cloud, .NET (5+) , .NET F...
# ...                                                  ...
# 46883  [C#, Go, Python, Ansible, Docker, Homebrew, Ku...
# 46884  [Bash/Shell (all shells), HTML/CSS, Java, Java...
#
#                                  AllSkillsWantToWorkWith
# 0      [Bash/Shell (all shells), Go, HTML/CSS, Java, ...
# 1      [C#, MSBuild, ASP.NET CORE, .NET (5+) , .NET F...
# ...                                                  ...
# 46883  [Go, Python, Ansible, Docker, Homebrew, Kubern...
# 46884  [Bash/Shell (all shells), HTML/CSS, Java, Java...
#
# [46885 rows x 48 columns]

# %%
# Create job profiles for training set
job_profiles_train = create_job_profiles(train_df)

# %%
# Prepare data for interaction matrix (training set)
df_have_train = train_df.explode('AllSkillsHaveWorkedWith')[['ResponseId', 'AllSkillsHaveWorkedWith']].reset_index(drop=True)
df_have_train = df_have_train.groupby('ResponseId')['AllSkillsHaveWorkedWith'].apply(list).reset_index()

# %%
df_have_train
# Out:
#        ResponseId                            AllSkillsHaveWorkedWith
# 0               2  [Bash/Shell (all shells), Go, HTML/CSS, Java, ...
# 1               3  [C#, MSBuild, Google Cloud, .NET (5+) , .NET F...
# 2               4  [C, C++, HTML/CSS, Java, JavaScript, PHP, Powe...
# 3               5  [C++, HTML/CSS, JavaScript, Lua, Python, Rust,...
# 4               7             [R, empty, empty, empty, empty, empty]
# ...           ...                                                ...
# 46880       55780  [Bash/Shell (all shells), Java, PHP, SQL, Dock...
# 46881       55781  [C#, GDScript, HTML/CSS, JavaScript, PowerShel...
# 46882       55783  [JavaScript, TypeScript, npm, Webpack, Microso...
# 46883       55784  [C#, Go, Python, Ansible, Docker, Homebrew, Ku...
# 46884       55785  [Bash/Shell (all shells), HTML/CSS, Java, Java...
#
# [46885 rows x 2 columns]

# %%
job_profiles_train
# Out:
#                                           DevType  \
# 0                             Academic researcher
# 1                                      Blockchain
# 2                   Cloud infrastructure engineer
# 3                                   Data engineer
# 4                        Data or business analyst
# 5   Data scientist or machine learning specialist
# 6                          Database administrator
# 7                                        Designer
# 8                               DevOps specialist
# 9                              Developer Advocate
# 10                           Developer Experience
# 11                                  Developer, AI
# 12                          Developer, QA or test
# 13                            Developer, back-end
# 14  Developer, desktop or enterprise applications
# 15    Developer, embedded applications or devices
# 16                           Developer, front-end
# 17                          Developer, full-stack
# 18                    Developer, game or graphics
# 19                              Developer, mobile
# 20                                       Educator
# 21                     Engineer, site reliability
# 22                            Engineering manager
# 23                              Hardware Engineer
# 24                Marketing or sales professional
# 25                                Product manager
# 26                                Project manager
# 27                    Research & Development role
# 28                                      Scientist
# 29                          Security professional
# 30           Senior Executive (C-Suite, VP, etc.)
# 31                           System administrator
#
#                                          TopLanguages  \
# 0   [Python, Bash/Shell (all shells), C++, C, Java...
# 1   [JavaScript, TypeScript, Python, Rust, HTML/CS...
# 2   [Python, Bash/Shell (all shells), JavaScript, ...
# 3   [Python, SQL, Bash/Shell (all shells), JavaScr...
# 4   [SQL, Python, JavaScript, HTML/CSS, Bash/Shell...
# 5   [Python, SQL, Bash/Shell (all shells), JavaScr...
# 6   [SQL, Bash/Shell (all shells), Python, HTML/CS...
# 7   [HTML/CSS, JavaScript, Python, SQL, TypeScript...
# 8   [Python, Bash/Shell (all shells), SQL, JavaScr...
# 9   [JavaScript, HTML/CSS, Python, SQL, TypeScript...
# 10  [JavaScript, Python, Bash/Shell (all shells), ...
# 11  [Python, JavaScript, HTML/CSS, SQL, Bash/Shell...
# 12  [Python, JavaScript, SQL, Java, HTML/CSS, Bash...
# 13  [SQL, JavaScript, Python, Java, HTML/CSS, Bash...
# 14  [SQL, C#, Python, JavaScript, C++, HTML/CSS, B...
# 15  [C, Python, C++, Bash/Shell (all shells), Java...
# 16  [JavaScript, HTML/CSS, TypeScript, SQL, Python...
# 17  [JavaScript, HTML/CSS, SQL, TypeScript, Python...
# 18  [C++, C#, Python, JavaScript, HTML/CSS, C, Bas...
# 19  [Kotlin, Java, Swift, JavaScript, Dart, SQL, P...
# 20  [Python, JavaScript, HTML/CSS, SQL, Bash/Shell...
# 21  [Python, Bash/Shell (all shells), SQL, JavaScr...
# 22  [JavaScript, SQL, Python, HTML/CSS, TypeScript...
# 23  [Python, C, C++, Bash/Shell (all shells), Java...
# 24  [HTML/CSS, JavaScript, SQL, Python, PHP, TypeS...
# 25  [JavaScript, SQL, Python, HTML/CSS, C#, Bash/S...
# 26  [JavaScript, SQL, HTML/CSS, Python, C#, PHP, J...
# 27  [Python, C++, Bash/Shell (all shells), JavaScr...
# 28  [Python, Bash/Shell (all shells), C++, C, R, S...
# 29  [Python, JavaScript, Bash/Shell (all shells), ...
# 30  [JavaScript, SQL, HTML/CSS, Python, TypeScript...
# 31  [Python, Bash/Shell (all shells), HTML/CSS, Ja...
#
#                                              TopTools  \
# 0   [Pip, Docker, Make, npm, Homebrew, APT, Pacman...
# 1   [Docker, npm, Yarn, Make, Pip, Homebrew, Kuber...
# 2   [Docker, Kubernetes, Terraform, Pip, npm, Home...
# 3   [Docker, Pip, Kubernetes, Homebrew, Terraform,...
# 4   [Pip, Docker, npm, Visual Studio Solution, Mak...
# 5   [Pip, Docker, Make, npm, Homebrew, Kubernetes,...
# 6   [Docker, Ansible, Visual Studio Solution, Terr...
# 7   [npm, Docker, Vite, Homebrew, Pip, Yarn, Visua...
# 8   [Docker, Kubernetes, Terraform, Pip, Ansible, ...
# 9   [npm, Docker, Pip, Homebrew, Kubernetes, Gradl...
# 10  [Docker, npm, Make, Pip, Kubernetes, Homebrew,...
# 11  [Docker, Pip, npm, Make, Homebrew, Kubernetes,...
# 12  [Docker, npm, Pip, Maven (build tool), Homebre...
# 13  [Docker, npm, Kubernetes, Pip, Homebrew, Maven...
# 14  [Visual Studio Solution, Docker, NuGet, MSBuil...
# 15  [Make, Docker, Pip, Ninja, Google Test, npm, A...
# 16  [npm, Vite, Webpack, Yarn, Docker, Homebrew, p...
# 17  [npm, Docker, Vite, Webpack, Yarn, Pip, Homebr...
# 18  [Unity 3D, Visual Studio Solution, Unreal Engi...
# 19  [Gradle, Homebrew, npm, Docker, Pip, Dagger, M...
# 20  [npm, Pip, Docker, Make, Homebrew, Vite, Gradl...
# 21  [Docker, Kubernetes, Pip, Terraform, npm, Make...
# 22  [Docker, npm, Homebrew, Kubernetes, Pip, Terra...
# 23  [Pip, Make, Docker, Visual Studio Solution, np...
# 24  [npm, Docker, Kubernetes, Pip, Homebrew, Webpa...
# 25  [Docker, npm, Pip, Homebrew, Make, Visual Stud...
# 26  [npm, Docker, Pip, Visual Studio Solution, NuG...
# 27  [Docker, Pip, Make, npm, Kubernetes, Visual St...
# 28  [Pip, Docker, Make, Homebrew, npm, APT, Ninja,...
# 29  [Docker, Pip, Make, npm, Kubernetes, APT, Home...
# 30  [Docker, npm, Homebrew, Pip, Kubernetes, Webpa...
# 31  [Docker, Pip, npm, Make, Ansible, APT, Homebre...
#
#                                      TopWebFrameworks  \
# 0   [Node.js, React, Flask, Django, jQuery, WordPr...
# 1   [Node.js, React, Next.js, Express, Angular, Ne...
# 2   [Node.js, React, Flask, FastAPI, Django, ASP.N...
# 3   [FastAPI, Flask, Node.js, React, Django, jQuer...
# 4   [Node.js, React, WordPress, Flask, Django, jQu...
# 5   [Flask, FastAPI, Django, Node.js, React, jQuer...
# 6   [Node.js, jQuery, ASP.NET, WordPress, ASP.NET ...
# 7   [React, Node.js, WordPress, jQuery, Next.js, S...
# 8   [Node.js, Flask, React, Django, jQuery, Spring...
# 9   [Node.js, React, jQuery, WordPress, ASP.NET CO...
# 10  [React, Node.js, jQuery, Express, FastAPI, Vue...
# 11  [FastAPI, Node.js, React, Flask, Django, Next....
# 12  [Node.js, React, Angular, Django, Flask, Sprin...
# 13  [Node.js, React, Spring Boot, ASP.NET CORE, jQ...
# 14  [ASP.NET CORE, Node.js, ASP.NET, jQuery, React...
# 15  [Node.js, React, Flask, jQuery, Django, Vue.js...
# 16  [React, Node.js, Next.js, Express, Angular, Vu...
# 17  [React, Node.js, jQuery, Express, Angular, ASP...
# 18  [Node.js, React, ASP.NET CORE, Next.js, Expres...
# 19  [Node.js, React, Next.js, Express, WordPress, ...
# 20  [Node.js, React, Express, Flask, jQuery, Next....
# 21  [Node.js, React, Flask, Express, Django, jQuer...
# 22  [React, Node.js, Angular, jQuery, ASP.NET CORE...
# 23  [Node.js, React, jQuery, Vue.js, Django, Flask...
# 24  [WordPress, Node.js, React, Next.js, jQuery, D...
# 25  [Node.js, React, jQuery, WordPress, ASP.NET CO...
# 26  [Node.js, jQuery, React, ASP.NET CORE, WordPre...
# 27  [Node.js, React, Flask, FastAPI, Django, ASP.N...
# 28  [Node.js, WordPress, Flask, Django, React, jQu...
# 29  [Node.js, React, Flask, WordPress, jQuery, Dja...
# 30  [React, Node.js, jQuery, Next.js, ASP.NET CORE...
# 31  [Node.js, WordPress, jQuery, React, Flask, Dja...
#
#                                          TopDatabases  \
# 0   [SQLite, PostgreSQL, MySQL, MongoDB, MariaDB, ...
# 1   [PostgreSQL, SQLite, MySQL, MongoDB, Redis, Ma...
# 2   [PostgreSQL, MySQL, Redis, SQLite, Dynamodb, E...
# 3   [PostgreSQL, Microsoft SQL Server, MySQL, SQLi...
# 4   [Microsoft SQL Server, PostgreSQL, MySQL, SQLi...
# 5   [PostgreSQL, SQLite, MySQL, Microsoft SQL Serv...
# 6   [Microsoft SQL Server, PostgreSQL, Oracle, MyS...
# 7   [MySQL, PostgreSQL, SQLite, MongoDB, Microsoft...
# 8   [PostgreSQL, MySQL, Redis, SQLite, Elasticsear...
# 9   [PostgreSQL, SQLite, MySQL, MongoDB, Microsoft...
# 10  [PostgreSQL, MySQL, SQLite, MongoDB, Microsoft...
# 11  [PostgreSQL, MySQL, SQLite, MongoDB, Redis, El...
# 12  [PostgreSQL, MySQL, SQLite, Microsoft SQL Serv...
# 13  [PostgreSQL, MySQL, Redis, SQLite, MongoDB, Mi...
# 14  [Microsoft SQL Server, SQLite, PostgreSQL, MyS...
# 15  [SQLite, PostgreSQL, MySQL, MariaDB, MongoDB, ...
# 16  [PostgreSQL, MySQL, MongoDB, SQLite, Microsoft...
# 17  [PostgreSQL, MySQL, Microsoft SQL Server, SQLi...
# 18  [SQLite, MySQL, PostgreSQL, MongoDB, MariaDB, ...
# 19  [SQLite, MySQL, PostgreSQL, Firebase Realtime ...
# 20  [MySQL, SQLite, PostgreSQL, MariaDB, MongoDB, ...
# 21  [PostgreSQL, MySQL, Redis, SQLite, Elasticsear...
# 22  [PostgreSQL, MySQL, Redis, SQLite, Microsoft S...
# 23  [MySQL, SQLite, PostgreSQL, MariaDB, Microsoft...
# 24  [MySQL, PostgreSQL, SQLite, Microsoft SQL Serv...
# 25  [PostgreSQL, MySQL, SQLite, Microsoft SQL Serv...
# 26  [MySQL, PostgreSQL, Microsoft SQL Server, SQLi...
# 27  [PostgreSQL, SQLite, MySQL, MongoDB, Microsoft...
# 28  [SQLite, PostgreSQL, MySQL, MariaDB, MongoDB, ...
# 29  [PostgreSQL, SQLite, MySQL, MariaDB, Elasticse...
# 30  [PostgreSQL, MySQL, Redis, SQLite, Microsoft S...
# 31  [MySQL, PostgreSQL, SQLite, MariaDB, Microsoft...
#
#                                          TopPlatforms  \
# 0   [Amazon Web Services (AWS), Google Cloud, Micr...
# 1   [Amazon Web Services (AWS), Google Cloud, Verc...
# 2   [Amazon Web Services (AWS), Microsoft Azure, G...
# 3   [Amazon Web Services (AWS), Microsoft Azure, G...
# 4   [Amazon Web Services (AWS), Microsoft Azure, G...
# 5   [Amazon Web Services (AWS), Microsoft Azure, G...
# 6   [Amazon Web Services (AWS), Microsoft Azure, O...
# 7   [Amazon Web Services (AWS), Cloudflare, Google...
# 8   [Amazon Web Services (AWS), Microsoft Azure, G...
# 9   [Amazon Web Services (AWS), Google Cloud, Micr...
# 10  [Amazon Web Services (AWS), Google Cloud, Clou...
# 11  [Amazon Web Services (AWS), Google Cloud, Micr...
# 12  [Amazon Web Services (AWS), Microsoft Azure, G...
# 13  [Amazon Web Services (AWS), Microsoft Azure, G...
# 14  [Microsoft Azure, Amazon Web Services (AWS), G...
# 15  [Amazon Web Services (AWS), Microsoft Azure, G...
# 16  [Amazon Web Services (AWS), Vercel, Firebase, ...
# 17  [Amazon Web Services (AWS), Microsoft Azure, G...
# 18  [Amazon Web Services (AWS), Google Cloud, Micr...
# 19  [Firebase, Google Cloud, Amazon Web Services (...
# 20  [Amazon Web Services (AWS), Google Cloud, Micr...
# 21  [Amazon Web Services (AWS), Google Cloud, Micr...
# 22  [Amazon Web Services (AWS), Microsoft Azure, G...
# 23  [Amazon Web Services (AWS), Microsoft Azure, G...
# 24  [Amazon Web Services (AWS), Google Cloud, Clou...
# 25  [Amazon Web Services (AWS), Microsoft Azure, G...
# 26  [Amazon Web Services (AWS), Microsoft Azure, G...
# 27  [Amazon Web Services (AWS), Microsoft Azure, G...
# 28  [Amazon Web Services (AWS), Google Cloud, Micr...
# 29  [Amazon Web Services (AWS), Microsoft Azure, G...
# 30  [Amazon Web Services (AWS), Google Cloud, Micr...
# 31  [Amazon Web Services (AWS), Microsoft Azure, G...
#
#                                          TopMiscTechs
# 0   [NumPy, Pandas, Scikit-Learn, Torch/PyTorch, T...
# 1   [Pandas, React Native, .NET (5+) , Apache Kafk...
# 2   [Pandas, NumPy, Apache Kafka, RabbitMQ, .NET (...
# 3   [Pandas, NumPy, Apache Spark, Apache Kafka, Sc...
# 4   [Pandas, NumPy, Scikit-Learn, Tidyverse, .NET ...
# 5   [Pandas, NumPy, Scikit-Learn, Torch/PyTorch, T...
# 6   [Pandas, .NET (5+) , .NET Framework (1.0 - 4.8...
# 7   [.NET (5+) , OpenGL, Flutter, NumPy, Electron,...
# 8   [Pandas, .NET (5+) , RabbitMQ, NumPy, Apache K...
# 9   [.NET (5+) , .NET Framework (1.0 - 4.8), Panda...
# 10  [.NET (5+) , RabbitMQ, Pandas, .NET Framework ...
# 11  [NumPy, Pandas, Torch/PyTorch, Scikit-Learn, T...
# 12  [.NET (5+) , Pandas, NumPy, Spring Framework, ...
# 13  [.NET (5+) , Spring Framework, Apache Kafka, R...
# 14  [.NET (5+) , .NET Framework (1.0 - 4.8), Qt, N...
# 15  [Qt, NumPy, Pandas, .NET (5+) , Opencv, .NET F...
# 16  [React Native, .NET (5+) , Flutter, Electron, ...
# 17  [.NET (5+) , .NET Framework (1.0 - 4.8), Panda...
# 18  [.NET (5+) , OpenGL, .NET Framework (1.0 - 4.8...
# 19  [Flutter, SwiftUI, React Native, .NET (5+) , K...
# 20  [Pandas, NumPy, .NET (5+) , Scikit-Learn, Tens...
# 21  [Pandas, NumPy, .NET (5+) , Apache Kafka, Rabb...
# 22  [.NET (5+) , RabbitMQ, Apache Kafka, Pandas, N...
# 23  [NumPy, Pandas, .NET (5+) , Qt, Opencv, .NET F...
# 24  [Pandas, NumPy, .NET (5+) , React Native, Open...
# 25  [.NET (5+) , Pandas, .NET Framework (1.0 - 4.8...
# 26  [.NET (5+) , .NET Framework (1.0 - 4.8), Panda...
# 27  [NumPy, Pandas, Scikit-Learn, Torch/PyTorch, O...
# 28  [NumPy, Pandas, Scikit-Learn, Torch/PyTorch, T...
# 29  [NumPy, .NET (5+) , Pandas, .NET Framework (1....
# 30  [.NET (5+) , Pandas, NumPy, RabbitMQ, Flutter,...
# 31  [.NET (5+) , .NET Framework (1.0 - 4.8), NumPy...

# %%
# Create interaction matrix for training set
interaction_matrix_train = create_interaction_matrix(df_have_train, job_profiles_train)
interaction_matrix_train
# Out:
# DevType     Academic researcher  Blockchain  Cloud infrastructure engineer  \
# ResponseId
# 2                      0.257576    0.317460                       0.296875
# 3                      0.014925    0.030303                       0.079365
# 4                      0.369231    0.348485                       0.328358
# 5                      0.145161    0.145161                       0.126984
# 7                      0.016667    0.000000                       0.000000
# ...                         ...         ...                            ...
# 55780                  0.215385    0.196970                       0.215385
# 55781                  0.159420    0.159420                       0.212121
# 55783                  0.063492    0.116667                       0.080645
# 55784                  0.128571    0.179104                       0.253968
# 55785                  0.378788    0.300000                       0.318841
#
# DevType     Data engineer  Data or business analyst  \
# ResponseId
# 2                0.276923                  0.220588
# 3                0.046154                  0.079365
# 4                0.369231                  0.308824
# 5                0.126984                  0.126984
# 7                0.000000                  0.016667
# ...                   ...                       ...
# 55780            0.253968                  0.196970
# 55781            0.194030                  0.250000
# 55783            0.080645                  0.080645
# 55784            0.215385                  0.179104
# 55785            0.338235                  0.338235
#
# DevType     Data scientist or machine learning specialist  \
# ResponseId
# 2                                                0.257576
# 3                                                0.014925
# 4                                                0.390625
# 5                                                0.145161
# 7                                                0.016667
# ...                                                   ...
# 55780                                            0.196970
# 55781                                            0.176471
# 55783                                            0.098361
# 55784                                            0.196970
# 55785                                            0.358209
#
# DevType     Database administrator  Designer  DevOps specialist  \
# ResponseId
# 2                         0.220588  0.301587           0.276923
# 3                         0.079365  0.080645           0.062500
# 4                         0.328358  0.353846           0.328358
# 5                         0.109375  0.129032           0.126984
# 7                         0.000000  0.000000           0.000000
# ...                            ...       ...                ...
# 55780                     0.196970  0.181818           0.253968
# 55781                     0.212121  0.215385           0.212121
# 55783                     0.063492  0.118644           0.098361
# 55784                     0.215385  0.147059           0.234375
# 55785                     0.281690  0.267606           0.318841
#
# DevType     Developer Advocate  ...  Engineering manager  Hardware Engineer  \
# ResponseId                      ...
# 2                     0.360656  ...             0.383333           0.202899
# 3                     0.096774  ...             0.079365           0.062500
# 4                     0.390625  ...             0.348485           0.328358
# 5                     0.126984  ...             0.126984           0.163934
# 7                     0.000000  ...             0.000000           0.000000
# ...                        ...  ...                  ...                ...
# 55780                 0.234375  ...             0.234375           0.179104
# 55781                 0.212121  ...             0.194030           0.194030
# 55783                 0.116667  ...             0.116667           0.063492
# 55784                 0.196970  ...             0.234375           0.112676
# 55785                 0.318841  ...             0.300000           0.318841
#
# DevType     Marketing or sales professional  Product manager  Project manager  \
# ResponseId
# 2                                  0.281250         0.276923         0.257576
# 3                                  0.080645         0.096774         0.096774
# 4                                  0.375000         0.390625         0.390625
# 5                                  0.111111         0.109375         0.126984
# 7                                  0.000000         0.000000         0.000000
# ...                                     ...              ...              ...
# 55780                              0.164179         0.215385         0.253968
# 55781                              0.179104         0.250000         0.230769
# 55783                              0.100000         0.098361         0.098361
# 55784                              0.218750         0.179104         0.161765
# 55785                              0.285714         0.338235         0.300000
#
# DevType     Research & Development role  Scientist  Security professional  \
# ResponseId
# 2                              0.257576   0.185714               0.257576
# 3                              0.096774   0.014925               0.062500
# 4                              0.348485   0.328358               0.348485
# 5                              0.126984   0.163934               0.145161
# 7                              0.000000   0.016667               0.000000
# ...                                 ...        ...                    ...
# 55780                          0.215385   0.161765               0.196970
# 55781                          0.230769   0.159420               0.194030
# 55783                          0.098361   0.063492               0.063492
# 55784                          0.196970   0.128571               0.234375
# 55785                          0.358209   0.338235               0.300000
#
# DevType     Senior Executive (C-Suite, VP, etc.)  System administrator
# ResponseId
# 2                                       0.383333              0.238806
# 3                                       0.079365              0.062500
# 4                                       0.369231              0.369231
# 5                                       0.109375              0.126984
# 7                                       0.000000              0.000000
# ...                                          ...                   ...
# 55780                                   0.215385              0.196970
# 55781                                   0.212121              0.212121
# 55783                                   0.116667              0.063492
# 55784                                   0.234375              0.179104
# 55785                                   0.300000              0.300000
#
# [46885 rows x 32 columns]

# %%
# Train the model
svd, user_factors_train, job_factors = train_svd_model(interaction_matrix_train)

# Reconstruct matrix for training set
reconstructed_train = np.dot(user_factors_train, job_factors.T)
reconstructed_train_df = pd.DataFrame(reconstructed_train, index=interaction_matrix_train.index, columns=interaction_matrix_train.columns)

# %%
# Evaluate on train set
true_jobs_train = train_df['DevType'].apply(lambda x: x[0] if isinstance(x, list) else x)
predicted_jobs_train = [reconstructed_train_df.loc[user].sort_values(ascending=False).index[:10] for user in reconstructed_train_df.index]

mrr_score_test = calculate_mrr(true_jobs_train, predicted_jobs_train)
print(f'MRR Score on Train Set: {mrr_score_test}')
# Out:
# MRR Score on Train Set: 0.32358198293361484

# %%
# Prepare data for interaction matrix (test set)
df_have_test = test_df.explode('AllSkillsHaveWorkedWith')[['ResponseId', 'AllSkillsHaveWorkedWith']].reset_index(drop=True)
df_have_test = df_have_test.groupby('ResponseId')['AllSkillsHaveWorkedWith'].apply(list).reset_index()

# Create interaction matrix for test set (using job profiles from training set)
interaction_matrix_test = create_interaction_matrix(df_have_test, job_profiles_train)

# Transform test set
user_factors_test = svd.transform(interaction_matrix_test)
reconstructed_test = np.dot(user_factors_test, job_factors.T)
reconstructed_test_df = pd.DataFrame(reconstructed_test, index=interaction_matrix_test.index, columns=interaction_matrix_test.columns)

# Evaluate on test set
true_jobs_test = test_df['DevType'].apply(lambda x: x[0] if isinstance(x, list) else x)
predicted_jobs_test = [reconstructed_test_df.loc[user].sort_values(ascending=False).index[:10] for user in reconstructed_test_df.index]

mrr_score_test = calculate_mrr(true_jobs_test, predicted_jobs_test)
print(f'MRR Score on Test Set: {mrr_score_test}')

# Example: Get top 5 job recommendations for a specific user in the test set
user_id = interaction_matrix_test.index[2]
recommended_jobs = recommend_jobs_for_user(user_id, reconstructed_test_df, n=5)
print(f"Top job recommendations for user {user_id}: {recommended_jobs}")
# Out:
# MRR Score on Test Set: 0.2609004761904757
# Top job recommendations for user 55788: ['Developer, back-end', 'Developer, QA or test', 'Developer, desktop or enterprise applications', 'Data or business analyst', 'DevOps specialist']
